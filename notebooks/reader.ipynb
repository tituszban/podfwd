# %%
import feedparser

# %%
feed = feedparser.parse("https://storage.googleapis.com/tituszban-autopod/feed4.xml")
feed.entries
# Out:
# [{'title': 'TWiT 804: The Bento Box Satellite - CES 2021 preview, streaming video in 2020, goodbye FarmVille',
#   'title_detail': {'type': 'text/plain',
#    'language': None,
#    'base': 'https://storage.googleapis.com/tituszban-autopod/feed4.xml',
#    'value': 'TWiT 804: The Bento Box Satellite - CES 2021 preview, streaming video in 2020, goodbye FarmVille'},
#   'itunes_title': 'The Bento Box Satellite - CES 2021 preview, streaming video in 2020, goodbye FarmVille',
#   'itunes_episodetype': 'full',
#   'published': 'Sun, 03 Jan 2021 17:15:09 PST',
#   'published_parsed': time.struct_time(tm_year=2021, tm_mon=1, tm_mday=4, tm_hour=1, tm_min=15, tm_sec=9, tm_wday=0, tm_yday=4, tm_isdst=0),
#   'itunes_episode': '804',
#   'links': [{'rel': 'alternate',
#     'type': 'text/html',
#     'href': 'https://twit.tv/shows/this-week-in-tech/episodes/804'},
#    {'length': '61814994',
#     'type': 'audio/mpeg',
# ...
